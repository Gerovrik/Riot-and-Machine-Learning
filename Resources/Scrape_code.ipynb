# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import csv

# %%
from splinter import Browser

# %%
import pandas as pd

# %%
url='https://commercial.century21.com/real-estate/san-antonio-tx/LCTXSANANTONIO/?kw=&pt=2,4,1,5,6,8'

# %%
response=requests.get(url)

# %%
soup= BeautifulSoup(response.text, 'html.parser')

# %%
#View of html 
#(soup.prettify())

# %%
results = soup.find_all('div', class_='card-container infinite-item col-md-6 col-lg-4')
#result

# %%
print(results)
# Out:
# [<div class="card-container infinite-item col-md-6 col-lg-4">
# <a class="property-card" data-brand-cd="REN" data-card-data='{
#    "id": "REN014698045",
#    "type": "sale",
#    "price": "$6,212,096",
#    "link": "/listing/hotel-2-59-acres-on-w-interstate-10-san-antonio-tx-78213-REN014698045",
#    "image": "https://www.century21.com/listhub/photo/maxxmax/photos.listhub.net/SABORTX/1501967/1?lm=20210103T231738",
#    "title": "Multi-Use",
#    "address": "Hotel + 2.59 Acres on W Interstate 10",
#    "location": "San Antonio, TX 78213",
#    "size_sqft": "Building:  41,384 sq. ft.",
#    "size_land": " Land: 4.8 Acres",
#    "lease_term": "",
#    "provider": "Courtesy Of Uriah Real Estate Organization LLC",
#    "provider_address": ""
# ...

# %%
df = pd.DataFrame(columns=["latitude","longitude"])

# %%
for result in results:  
    longitude = df.columns[result]
    try:
        longt= result.a['data-longitude']
        
        lat= result.a['data-latitude']


        zipcode = result.a['data-zipcode']
        count += zipcode.count(zipcode)

        print(f'{lat}, {longt}')
        print(f'zipcode:{zipcode}')
        print(count)

    except Exception as e:
        print(e)

count = 0
# Out:
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-3529ad2d804c> in <module>
# ----> 1 df = pd.read_csv('Cent21scrape.csv',
#       2             index_col='count',
#       3             header=0,
#       4             names=['count', 'lat', 'longt', 'zipcode'])
#       5 df.to_csv('hrdata_modified.csv')
#
# ...

# %%
    # # Error handling
    # try:
    #     news_title = result.a['data-card-data']
    #     # news_p = result.a.text
    #     longt= result.a["data-longitude’]
    #     lat= result.a[‘data-latitude’]
    #     zipcode = result.a[‘data-zipcode’]
    #     print(f’Property Info:{news_title}‘)
    #     # print(f’Details:{news_p}‘)
    #     print(f’Long & Lat: {lat}, {longt}‘)
    #     print(f’Zipcode:{zipcode}‘)
    #     print(‘-------------’)
    # except Exception as e:
    #     print(e)
# Out:
#   File "<ipython-input-48-30d37398afff>", line 3
#     news_title = result.a[‘data-card-data’]
#                               ^
# SyntaxError: invalid character in identifier
